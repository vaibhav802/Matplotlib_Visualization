# %% [markdown]
# # Save fig

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.pie([1,2,3], autopct="%0.1f%%")
plt.savefig("Chart", dpi = 100, quality = 99, facecolor = "k")
plt.show()
